# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Exploring-market-risk-factor-data" data-toc-modified-id="Exploring-market-risk-factor-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exploring market risk-factor data</a></span><ul class="toc-item"><li><span><a href="#Exploring-risk-factor-time-series:-equity-indexes" data-toc-modified-id="Exploring-risk-factor-time-series:-equity-indexes-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Exploring risk-factor time series: equity indexes</a></span></li><li><span><a href="#Exploring-risk-factor-time-series:-individual-equities" data-toc-modified-id="Exploring-risk-factor-time-series:-individual-equities-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Exploring risk-factor time series: individual equities</a></span></li><li><span><a href="#Exploring-risk-factor-time-series:-exchange-rates" data-toc-modified-id="Exploring-risk-factor-time-series:-exchange-rates-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Exploring risk-factor time series: exchange rates</a></span></li><li><span><a href="#Explore-return-series" data-toc-modified-id="Explore-return-series-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Explore return series</a></span></li><li><span><a href="#Different-ways-of-plotting-risk-factor-and-return-series" data-toc-modified-id="Different-ways-of-plotting-risk-factor-and-return-series-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Different ways of plotting risk-factor and return series</a></span></li><li><span><a href="#Aggregating-log-return-series" data-toc-modified-id="Aggregating-log-return-series-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Aggregating log-return series</a></span></li><li><span><a href="#Commodities-data" data-toc-modified-id="Commodities-data-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Commodities data</a></span></li><li><span><a href="#Interest-rate-data" data-toc-modified-id="Interest-rate-data-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Interest-rate data</a></span></li></ul></li><li><span><a href="#Real-world-returns-are-riskier-than-normal" data-toc-modified-id="Real-world-returns-are-riskier-than-normal-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Real world returns are riskier than normal</a></span><ul class="toc-item"><li><span><a href="#Graphical-methods-for-assessing-normality" data-toc-modified-id="Graphical-methods-for-assessing-normality-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Graphical methods for assessing normality</a></span></li><li><span><a href="#Q-Q-plots-for-assessing-normality" data-toc-modified-id="Q-Q-plots-for-assessing-normality-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Q-Q plots for assessing normality</a></span></li><li><span><a href="#Numerical-tests-of-normality" data-toc-modified-id="Numerical-tests-of-normality-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Numerical tests of normality</a></span></li><li><span><a href="#Testing-normality-for-longer-time-horizons" data-toc-modified-id="Testing-normality-for-longer-time-horizons-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Testing normality for longer time horizons</a></span></li><li><span><a href="#Overlaping-returns" data-toc-modified-id="Overlaping-returns-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Overlaping returns</a></span></li><li><span><a href="#Fitting-the-Student-t-disribution-to-data" data-toc-modified-id="Fitting-the-Student-t-disribution-to-data-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Fitting the Student t disribution to data</a></span></li><li><span><a href="#Testing-FX-returns-for-normality" data-toc-modified-id="Testing-FX-returns-for-normality-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Testing FX returns for normality</a></span></li><li><span><a href="#Testing-interest-rate-returns-for-normality" data-toc-modified-id="Testing-interest-rate-returns-for-normality-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Testing interest-rate returns for normality</a></span></li><li><span><a href="#Testing-gold-price-returns-for-normality" data-toc-modified-id="Testing-gold-price-returns-for-normality-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Testing gold price returns for normality</a></span></li></ul></li><li><span><a href="#Real-world-returns-are-volatile-and-correlated" data-toc-modified-id="Real-world-returns-are-volatile-and-correlated-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Real world returns are volatile and correlated</a></span><ul class="toc-item"><li><span><a href="#Spotting-a-volatile-time-series" data-toc-modified-id="Spotting-a-volatile-time-series-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Spotting a volatile time series</a></span></li><li><span><a href="#Using-acf-plots-to-reveal-volatility" data-toc-modified-id="Using-acf-plots-to-reveal-volatility-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Using acf plots to reveal volatility</a></span></li><li><span><a href="#Applying-Ljung-Box-tests-to-return-data" data-toc-modified-id="Applying-Ljung-Box-tests-to-return-data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Applying Ljung-Box tests to return data</a></span></li><li><span><a href="#Applying-Ljung-Box-tests-to-longer-interval-return-data" data-toc-modified-id="Applying-Ljung-Box-tests-to-longer-interval-return-data-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Applying Ljung-Box tests to longer-interval return data</a></span></li><li><span><a href="#Extreme-values-in-volatile-time-series" data-toc-modified-id="Extreme-values-in-volatile-time-series-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Extreme values in volatile time series</a></span></li><li><span><a href="#Cross-correlations-between-risk-factor-return-series" data-toc-modified-id="Cross-correlations-between-risk-factor-return-series-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Cross correlations between risk-factor return series</a></span></li><li><span><a href="#Volatility-and-correlation-of-FX-returns" data-toc-modified-id="Volatility-and-correlation-of-FX-returns-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Volatility and correlation of FX returns</a></span></li><li><span><a href="#Volatility-and-correlation-of-interest-rate-data" data-toc-modified-id="Volatility-and-correlation-of-interest-rate-data-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Volatility and correlation of interest-rate data</a></span></li></ul></li><li><span><a href="#Estimating-portfolio-value-at-risk-(VaR)" data-toc-modified-id="Estimating-portfolio-value-at-risk-(VaR)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Estimating portfolio value-at-risk (VaR)</a></span><ul class="toc-item"><li><span><a href="#Computing-VaR-and-ES-for-normal-distribution" data-toc-modified-id="Computing-VaR-and-ES-for-normal-distribution-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Computing VaR and ES for normal distribution</a></span></li><li><span><a href="#Estimating-risk-factors-for-international-equity-portfolio" data-toc-modified-id="Estimating-risk-factors-for-international-equity-portfolio-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Estimating risk factors for international equity portfolio</a></span></li><li><span><a href="#Historical-simulation" data-toc-modified-id="Historical-simulation-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Historical simulation</a></span></li><li><span><a href="#Estimating-VaR-and-ES" data-toc-modified-id="Estimating-VaR-and-ES-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Estimating VaR and ES</a></span></li><li><span><a href="#Compute-Black-Scholes-price-of-an-option" data-toc-modified-id="Compute-Black-Scholes-price-of-an-option-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Compute Black-Scholes price of an option</a></span></li><li><span><a href="#Equity-and-implied-volatility-risk-factors" data-toc-modified-id="Equity-and-implied-volatility-risk-factors-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Equity and implied volatility risk factors</a></span></li><li><span><a href="#Historical-simulation-of-losses-for-option-portfolio" data-toc-modified-id="Historical-simulation-of-losses-for-option-portfolio-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Historical simulation of losses for option portfolio</a></span></li><li><span><a href="#Estimating-VaR-and-ES-for-weekly-losses" data-toc-modified-id="Estimating-VaR-and-ES-for-weekly-losses-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Estimating VaR and ES for weekly losses</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Exploring market risk-factor data

# %% [markdown]
# ### Exploring risk-factor time series: equity indexes

# %%
# Load quantmod package
library(quantmod)
# Out:
# Warning message:
# "package 'quantmod' was built under R version 3.6.1"Loading required package: xts
# Loading required package: zoo
# Warning message:
# "package 'zoo' was built under R version 3.6.1"
# Attaching package: 'zoo'
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
#
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Loading required package: TTR
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Version 0.4-0 included new data defaults. See ?getSymbols.

# %%
# Install qrmdata package
install.packages('qrmdata')
# Out:
# Installing package into 'C:/Users/Robert Brown/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'qrmdata' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Robert Brown\AppData\Local\Temp\RtmpOQQkVz\downloaded_packages

# %%
# Load qrmdata package
library(qrmdata)
# Out:
# Warning message:
# "package 'qrmdata' was built under R version 3.6.2"

# %%
# Load DJ index
load('DJ.rda')

# %%
# Show head() and tail() of DJ index
head(DJ)
tail(DJ)
# Out:
#               ^DJI
# 1985-01-29 1292.62
# 1985-01-30 1287.88
# 1985-01-31 1286.77
# 1985-02-01 1277.72
# 1985-02-04 1290.08
# 1985-02-05 1285.23
#                ^DJI
# 2015-12-23 17602.61
# 2015-12-24 17552.17
# 2015-12-28 17528.27
# 2015-12-29 17720.98
# 2015-12-30 17603.87
# 2015-12-31 17425.03

# %%
plot(DJ)
# Out:
# plot without title

# %%
# Extract 2008-2009 and assign to dj0809
dj0809 <- DJ['2008/2009']

# %%
# Plot dj0809
plot(dj0809)
# Out:
# plot without title

# %% [markdown]
# ### Exploring risk-factor time series: individual equities

# %%
# Load DJ constituents data
load('DJ_const.rda')

# %%
# Apply names() and head() to DJ_const
names(DJ_const)
head(DJ_const)
# Out:
#  [1] "AAPL" "AXP"  "BA"   "CAT"  "CSCO" "CVX"  "DD"   "DIS"  "GE"   "GS"
# [11] "HD"   "IBM"  "INTC" "JNJ"  "JPM"  "KO"   "MCD"  "MMM"  "MRK"  "MSFT"
# [21] "NKE"  "PFE"  "PG"   "TRV"  "UNH"  "UTX"  "V"    "VZ"   "WMT"  "XOM"
#            AAPL AXP       BA      CAT CSCO CVX       DD      DIS       GE GS HD
# 1962-01-02   NA  NA 0.212905 0.593184   NA  NA 1.227958 0.061014 0.145967 NA NA
# 1962-01-03   NA  NA 0.217163 0.598964   NA  NA 1.229230 0.061832 0.144501 NA NA
# 1962-01-04   NA  NA 0.215034 0.614372   NA  NA 1.220331 0.061832 0.142794 NA NA
# 1962-01-05   NA  NA 0.210773 0.620152   NA  NA 1.187280 0.062039 0.139132 NA NA
# 1962-01-08   NA  NA 0.211306 0.624001   NA  NA 1.169484 0.061832 0.138889 NA NA
# 1962-01-09   NA  NA 0.211839 0.629777   NA  NA 1.173297 0.063060 0.139620 NA NA
#                 IBM INTC JNJ JPM       KO MCD MMM MRK MSFT NKE PFE PG TRV UNH
# 1962-01-02 2.346625   NA  NA  NA 0.031031  NA  NA  NA   NA  NA  NA NA  NA  NA
# ...

# %%
# Extract AAPL and GS in 2008-09 and assign to stocks
stocks <- DJ_const['2008/2009', c('AAPL', 'GS')]

# %%
# Plot stocks with plot.zoo()
plot.zoo(stocks)
# Out:
# Plot with title "stocks"

# %% [markdown]
# ### Exploring risk-factor time series: exchange rates

# %%
# Load exchange rate data
load("GBP_USD.rda")
load("EUR_USD.rda")

# %%
# Plot the two exchange rates
plot(GBP_USD)
plot(EUR_USD)
# Out:
# plot without title
# plot without title

# %%
# Plot a USD_GBP exchange rate
plot(1/GBP_USD)
# Out:
# plot without title

# %%
# Merge the two exchange rates GBP_USD and EUR_USD
fx <- merge(GBP_USD, EUR_USD, all = TRUE)

# %%
# Extract 2010-15 data from fx and assign to fx0015
fx0015 <- fx["2010/2015"]

# %%
# Plot the exchange rates in fx0015
plot.zoo(fx0015)
# Out:
# Plot with title "fx0015"

# %% [markdown]
# ### Explore return series

# %%
# Compute the log-returns of dj0809 and assign to dj0809_x
dj0809_x <- diff(log(dj0809))[-1]

# %%
# Plot the log-returns
plot(dj0809_x)
# Out:
# plot without title

# %%
# Compute the log-returns of djstocks and assign to djstocks_x
djstocks_x <- diff(log(stocks))[-1]

# %%
# Plot the two share returns
plot.zoo(djstocks_x)
# Out:
# Plot with title "djstocks_x"

# %%
# Compute the log-returns of GBP_USD and assign to erate_x
erate_x <- diff(log(GBP_USD))[-1]

# %%
# Plot the log-returns of the GBP_USD exchange rate
plot(erate_x)
# Out:
# plot without title

# %% [markdown]
# ### Different ways of plotting risk-factor and return series

# %%
djstocks <- DJ_const['2008/2009', c('AAPL','AXP','BA','CAT')]

# %%
# Plot djstocks in four separate plots
plot.zoo(djstocks)
# Out:
# Plot with title "djstocks"

# %%
# Plot djstocks in one plot and add legend
plot.zoo(djstocks, plot.type = "single", col = 1:4)
legend(julian(x = as.Date("2009-01-01")), y = 70, legend = names(DJ_const)[1:4], fill = 1:4)
# Out:
# Plot with title ""

# %%
# Compute log-returns and assign to djstocks_x
djstocks_x <- diff(log(djstocks))[-1]

# %%
# Plot djstocks_x in four separate plots
plot.zoo(djstocks_x)
# Out:
# Plot with title "djstocks_x"

# %% [markdown]
# ### Aggregating log-return series

# %%
# Extract 2010-2015 and assign to dj1015
dj1015 <- DJ['2010/2015']

# %%
# Compute log-returns and assign to djx
djx <- diff(log(dj1015))[-1]

# %%
head(djx)
# Out:
#                     ^DJI
# 2010-01-05 -0.0011287997
# 2010-01-06  0.0001570208
# 2010-01-07  0.0031331299
# 2010-01-08  0.0010676138
# 2010-01-11  0.0043040584
# 2010-01-12 -0.0034502910

# %%
# Plot djx
plot(djx)
# Out:
# plot without title

# %%
# Plot weekly log-returns of djx
plot(apply.weekly(djx, sum), type = "h")
# Out:
# plot without title

# %%
# Plot monthly log-returns of djx
plot(apply.monthly(djx, sum), type = "h")
# Out:
# plot without title

# %%
djreturns <- diff(log(djstocks))[-1]

# %%
# Plot djreturns
plot.zoo(djreturns)
# Out:
# Plot with title "djreturns"

# %%
# Plot monthly log-returns of djstocks_x
plot.zoo(apply.monthly(djreturns, colSums), type = "h")
# Out:
# Plot with title "apply.monthly(djreturns, colSums)"

# %% [markdown]
# ### Commodities data

# %%
load('GOLD.rda')
load('OIL_Brent.rda')

# %%
# Plot gold and oil prices
plot(GOLD)
plot(OIL_Brent)
# Out:
# plot without title
# plot without title

# %%
# Calculate daily log-returns
goldx <- diff(log(GOLD))[-1]
oilx <- diff(log(OIL_Brent))[-1]

# %%
# Calculate monthly log-returns
goldx_m <- apply.monthly(goldx, sum)
oilx_m <- apply.monthly(oilx, sum)

# %%
# Merge goldx_m and oilx_m into coms
coms <- merge(goldx_m, oilx_m)

# %%
# Plot coms with vertical bars
plot.zoo(coms, type="h")
# Out:
# Plot with title "coms"

# %%
# Make a pairwise scatterplot of coms
pairs(as.zoo(coms))
# Out:
# Plot with title ""

# %% [markdown]
# ### Interest-rate data

# %%
load('ZCB_CA.rda')

# %%
# Identify and create vector containing column names for 1, 5, 10 year yields
names(ZCB_CA)
yield_cols = c("1.00y", "5.00y", "10.00y")
# Out:
#   [1] "0.25y"  "0.50y"  "0.75y"  "1.00y"  "1.25y"  "1.50y"  "1.75y"  "2.00y"
#   [9] "2.25y"  "2.50y"  "2.75y"  "3.00y"  "3.25y"  "3.50y"  "3.75y"  "4.00y"
#  [17] "4.25y"  "4.50y"  "4.75y"  "5.00y"  "5.25y"  "5.50y"  "5.75y"  "6.00y"
#  [25] "6.25y"  "6.50y"  "6.75y"  "7.00y"  "7.25y"  "7.50y"  "7.75y"  "8.00y"
#  [33] "8.25y"  "8.50y"  "8.75y"  "9.00y"  "9.25y"  "9.50y"  "9.75y"  "10.00y"
#  [41] "10.25y" "10.50y" "10.75y" "11.00y" "11.25y" "11.50y" "11.75y" "12.00y"
#  [49] "12.25y" "12.50y" "12.75y" "13.00y" "13.25y" "13.50y" "13.75y" "14.00y"
#  [57] "14.25y" "14.50y" "14.75y" "15.00y" "15.25y" "15.50y" "15.75y" "16.00y"
#  [65] "16.25y" "16.50y" "16.75y" "17.00y" "17.25y" "17.50y" "17.75y" "18.00y"
#  [73] "18.25y" "18.50y" "18.75y" "19.00y" "19.25y" "19.50y" "19.75y" "20.00y"
#  [81] "20.25y" "20.50y" "20.75y" "21.00y" "21.25y" "21.50y" "21.75y" "22.00y"
#  [89] "22.25y" "22.50y" "22.75y" "23.00y" "23.25y" "23.50y" "23.75y" "24.00y"
# ...

# %%
# Compute log-returns as zcb_x and plot them for same maturities
zcb_x <- diff(log(ZCB_CA))[-1]
plot.zoo(zcb_x[, yield_cols])
# Out:
# Plot with title "zcb_x[, yield_cols]"

# %%
# Compute simple returns as zcb_x2 and plot them for same maturities
zcb_x2 <- diff(ZCB_CA)
plot.zoo(zcb_x2[, yield_cols])
# Out:
# Plot with title "zcb_x2[, yield_cols]"

# %%
# Make a vector containing the maturities                             
maturity <- (1:120)/4

# %%
# Plot the yield curve for the first day of zcb
plot(maturity, ZCB_CA[1, ], ylim = range(ZCB_CA), type = "l", ylab = "yield (%)", col = "red")
# Out:
# plot without title

# %%
# Plot the yield curve for the first day of zcb
plot(maturity, ZCB_CA[1, ], ylim = range(ZCB_CA), type = "l", ylab = "yield (%)", col = "red")

# Add a line for the last day of zcb
lines(maturity, ZCB_CA[nrow(ZCB_CA), ])
# Out:
# plot without title

# %%
# Estimate the 99th sample percentile of the distribution of hslosses
quantile(hslosses, 0.99)

# Estimate the 99% ES
mean(hslosses[hslosses >= quantile(hslosses, 0.99)])

# Estimate the mean and standard deviation of hslosses
mu <- mean(hslosses)
sigma <- sd(hslosses)

# Compute the 99% quantile of a normal distribution
qnorm(0.99, mu, sigma)

# Compute the 99% ES of a normal distribution
ESnorm(0.99, mu, sigma)

# %% [markdown]
# ### Compute Black-Scholes price of an option

# %%
library(qrmtools)

# %%
# Set the interest rate r to be 0.01, the volatility sigma to be 0.2 and the strike K to be 100
r <- 0.01
sigma <- 0.20
K <- 100.00

# Look at the arguments of the Black_Scholes function
args(Black_Scholes)

# Price a European call option that matures in one year if the current stock price is 80
Black_Scholes(0, 80, r, sigma, K, 1, "call")

# Price a European call option that matures in one year if the current stock price is 120
Black_Scholes(0, 120, r, sigma, K, 1, "call")

# Price a European put option that matures in one year if the current stock price is 80
Black_Scholes(0, 80, r, sigma, K, 1,"put")

# Price a European put option that matures in one year if the current stock price is 120
Black_Scholes(0, 120, r, sigma, K, 1, "put")
# Out:
# function (t, S, r, sigma, K, T, type = c("call", "put"))
# NULL
# [1] 1.302245
# [1] 22.94188
# [1] 20.30723
# [1] 1.94686

# %% [markdown]
# ### Equity and implied volatility risk factors

# %%
# Load VIX and SP500 data
load('VIX.rda')
load('SP500.rda')

# %%
# Merge VIX and SP500
riskfactors <- merge(VIX, SP500, all = TRUE)['1990/2010']

# %%
# length(VIX)
# length(SP500)
# length(riskfactors)

# %%
# str(riskfactors)

# %%
# Calcualte daily log-returns of riskfactors
returns <- diff(log(riskfactors))[-1]

# %%
# library(quantmod)

# %%
# library(moments)

# %%
# Plot the risk factors and the log-returns
# risk factors = SMI, GSPC, FTSE, CHF/GBP, USD,GBP
plot.zoo(riskfactors)
plot.zoo(returns)

# Make a scatterplot of the two return series
plot(as.matrix(returns))

# Apply the Jarque-Bera test to the returns and make a Q-Q plot of the volatility log-returns
apply(returns, 2, jarque.test)
qqnorm(returns[, 2])

# Create the sample acf of the returns and absolute returns
acf(returns)
acf(abs(returns))

# Calculate the correlation between the log-returns
cor(returns)
# Out:
# Plot with title "riskfactors"
# Plot with title "returns"
# $X.VIX
#
# 	Jarque-Bera Normality Test
#
# data:  newX[, i]
# JB = 4412.6, p-value < 2.2e-16
# alternative hypothesis: greater
#
#
# $X.GSPC
#
# 	Jarque-Bera Normality Test
#
# data:  newX[, i]
# JB = 17397, p-value < 2.2e-16
# alternative hypothesis: greater
# plot without title
# Plot with title "Normal Q-Q Plot"
# Plot with title "X.GSPC"
#        X.VIX      X.GSPC
# X.VIX   1.0000000 -0.6978308
# X.GSPC -0.6978308  1.0000000
# Plot with title "X.GSPC"

# %% [markdown]
# ### Historical simulation of losses for option portfolio

# %%
# Calculate the first loss
lossop(c(-0.1, -0.1), S = 80, sigma = 0.2)

# Calculate the second loss
lossop(c(-0.1, 0.1), S = 100, sigma = 0.2)

# Create and plot hslosses
hslosses <- lossop(returns, S = 100, sigma = 0.2)
plot(hslosses)

# Form a Q-Q plot of hslosses against normal
qqnorm(hslosses)

# Plot the sample acf of raw data and absolute values in hslosses
acf(hslosses)
acf(abs(hslosses))
# Out:
# Error in lossop(c(-0.1, -0.1), S = 80, sigma = 0.2): could not find function "lossop"
# Traceback:

# %% [markdown]
# ### Estimating VaR and ES for weekly losses

# %%
# Estimate the 99.5% percentile of the distribution
quantile(hslosses, 0.995)

# Estimate the 99.5% ES
mean(hslosses[hslosses >= quantile(hslosses, 0.995)])

# Estimate the mean and standard deviation of hslosses
mu <- mean(hslosses)
sigma <- sd(hslosses)

# Compute the 99.5% quantile of a normal distribution
qnorm(0.995, mu, sigma)

# Compute the 99.5% ES of a normal distribution
ESnorm(0.995, mu, sigma)
# Out:
# Error in quantile(hslosses, 0.995): object 'hslosses' not found
# Traceback:
#
# 1. quantile(hslosses, 0.995)

# %%
library(qrmtools)

# %%
library(QRM)

# %%
?VaR()

# %%
?ESnorm()
